# %% [markdown]
# # 03 EDA

# %%
import pandas as pd

# %%
shootings = pd.read_csv("../Data/Cleaned/clean_shootings.csv")
agencies = pd.read_csv("../Data/Cleaned/clean_agencies.csv")

# %%
print(shootings.head())
print(shootings.info())

print(shootings['race'].value_counts())
print(shootings['gender'].value_counts())
print(shootings['armed_with'].value_counts())
print(shootings['state'].value_counts())

shootings['year'] = pd.to_datetime(shootings['date']).dt.year
print(shootings.groupby('year').size())

print(shootings['age'].describe())
# Out:
#    id        date threat_type flee_status armed_with           city  \
# 0   3  2015-01-02       point         not        gun        Shelton
# 1   4  2015-01-02       point         not        gun          Aloha
# 2   5  2015-01-03        move         not    unarmed        Wichita
# 3   8  2015-01-04       point         not    replica  San Francisco
# 4   9  2015-01-04       point         not      other          Evans
#
#           county state   latitude   longitude                name   age  \
# 0          Mason    WA  47.246826 -123.121592          Tim Elliot  53.0
# 1     Washington    OR  45.487421 -122.891696    Lewis Lee Lembke  47.0
# 2       Sedgwick    KS  37.694766  -97.280554  John Paul Quintero  23.0
# 3  San Francisco    CA  37.762910 -122.422001     Matthew Hoffman  32.0
# 4           Weld    CO  40.383937 -104.692261   Michael Rodriguez  39.0
#
#   gender      race  was_mental_illness_related  body_camera agency_ids  \
# 0   male     Asian                        True        False         73
# 1   male     White                       False        False         70
# 2   male  Hispanic                       False        False        238
# 3   male     White                        True        False        196
# 4   male  Hispanic                       False        False        473
#
#    agency_id
# 0       73.0
# 1       70.0
# 2      238.0
# 3      196.0
# 4      473.0
# <class 'pandas.DataFrame'>
# RangeIndex: 11265 entries, 0 to 11264
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          11265 non-null  int64
#  1   date                        11265 non-null  str
#  2   threat_type                 11189 non-null  str
#  3   flee_status                 9662 non-null   str
#  4   armed_with                  11265 non-null  str
#  5   city                        11174 non-null  str
#  6   county                      6268 non-null   str
#  7   state                       11265 non-null  str
#  8   latitude                    10018 non-null  float64
#  9   longitude                   10017 non-null  float64
#  10  name                        10932 non-null  str
#  11  age                         10879 non-null  float64
#  12  gender                      11244 non-null  str
#  13  race                        11265 non-null  str
#  14  was_mental_illness_related  11265 non-null  bool
#  15  body_camera                 11265 non-null  bool
#  16  agency_ids                  11264 non-null  str
#  17  agency_id                   11264 non-null  float64
# dtypes: bool(2), float64(4), int64(1), str(11)
# memory usage: 1.4 MB
# None
# race
# White              5125
# Black              2641
# Hispanic           1814
# Unknown            1300
# Asian               190
# Native American     158
# Other                37
# Name: count, dtype: int64
# gender
# male          10746
# female          493
# non-binary        5
# Name: count, dtype: int64
# armed_with
# gun                          6631
# knife                        1845
# unarmed                       591
# undetermined                  498
# unknown                       404
# vehicle                       396
# replica                       361
# blunt_object                  260
# other                         112
# gun;vehicle                    48
# gun;knife                      46
# vehicle;gun                    28
# knife;knife                     6
# blunt_object;blunt_object       5
# knife;blunt_object              5
# other;gun                       4
# vehicle;knife                   4
# blunt_object;knife              3
# knife;vehicle                   3
# blunt_object;gun                3
# gun;other                       2
# knife;replica                   2
# replica;vehicle                 1
# vehicle;knife;other             1
# replica;knife                   1
# other;blunt_object;knife        1
# other;knife                     1
# blunt_object;other              1
# knife;unknown                   1
# replica;blunt_object            1
# Name: count, dtype: int64
# state
# CA    1460
# TX    1090
# FL     703
# AZ     483
# GA     433
# CO     397
# NC     324
# OH     323
# TN     315
# WA     301
# OK     286
# MO     286
# PA     246
# NM     246
# IN     244
# IL     226
# VA     218
# AL     216
# LA     212
# MI     207
# NY     207
# KY     201
# OR     200
# SC     188
# WI     187
# NV     181
# AR     160
# UT     150
# MS     147
# MD     140
# KS     123
# MN     121
# NJ     120
# WV     113
# ID     104
# AK      78
# MT      73
# IA      71
# MA      65
# ME      56
# NE      53
# HI      47
# WY      44
# SD      40
# CT      36
# NH      34
# DC      30
# ND      29
# DE      22
# VT      18
# RI      11
# Name: count, dtype: int64
# year
# 2015    1097
# 2016    1055
# 2017    1024
# 2018    1035
# 2019    1037
# 2020    1076
# 2021    1138
# 2022    1210
# 2023    1298
# 2024    1295
# dtype: int64
# count    10879.000000
# mean        37.590955
# std         12.912856
# min          0.000000
# 25%         28.000000
# 50%         36.000000
# 75%         46.000000
# max         92.000000
# Name: age, dtype: float64
